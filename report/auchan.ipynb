# %% [markdown]
# # Команда «K2»: кейс от компании Ашан:
#
# ## Использование искусственного интеллекта в работе контакт-центра

# %% [markdown]
# **Описание кейса:**
#
# Необходимо разработать AI-решение для поддержки контакт-центра, способное отвечать на общие вопросы о компании, обрабатывать запросы на возврат и предоставлять информацию о продуктах и услугах. AI должен взаимодействовать с клиентами, помогая подобрать продукт и генерировать ответы для операторов. Также AI будет анализировать отзывы клиентов для улучшения качества услуг. Решение может быть интегрировано в существующий чат-бот на сайте и в приложении, отвечать на запросы о работе магазина и ассортименте. Планируется создание текстового чат-бота с возможностью дополнения голосовым решением. Решение должно предоставлять аналитику о его использовании, иметь возможность рассылки сообщений и интеграции с CRM системой.

# %% [markdown]
# **Проблема:**
#
# Ашан испытывает проблему с большим количеством человеческих ресурсов, занятых обработкой запросов клиентов. Создание AI-решения для контакт-центра и чат-бота позволит обрабатывать больше запросов быстрее, снизит нагрузку на операторов, уменьшит очереди и позволит сотрудникам сосредоточиться на других задачах. Это приведет к снижению стоимости обслуживания клиентов и сокращению необходимых ресурсов.

# %% [markdown]
# **Ожидания:**
#
# Чат-бот должен быть способен генерировать осмысленные ответы на вопросы клиентов, собирать и анализировать данные клиентов из всех каналов (включая действия на сайте, тексты чатов, опросы, электронные письма) и на основе этого предлагать подходящие рекомендации.

# %% [markdown]
# **Функциональные требования:**
#
# - Качественное распознавание текста.
# - Соответствие бота заданному формату
# - Сгенерированный текст отвечает заданному в запросе стилю.
# - Итоговый текст не требует ручного редактирования.
# - Умение проводить анализ изображений. Точно определять, что именно находится на фотографии, вплоть до мелких деталей.
# - Приложение должно задавать пользователю грамотные вопросы для сбора данных о текущей проблеме.
# - Приложение должно анализировать информацию, предоставленную пользователем, и предлагать соответствующие рекомендации.
# - Приложение должно быть легким в использовании и иметь удобный интерфейс для ввода данных.
# - Приложение должно обеспечивать безопасность данных и конфиденциальность пользовательской информации.

# %% [markdown]
# **Дополнительная информация:**
#
# При разработке решения также необходимо предусмотреть функции, которые позволят модели обучаться и самообучаться. Это важно для обеспечения адаптивности и актуальности решения, так как данные и потребности пользователей могут меняться со временем.
#
# Особое внимание следует уделить мерам по обеспечению безопасности данных и конфиденциальности пользователей. Необходимо применить соответствующие технологии и методы для обеспечения защиты данных от несанкционированного доступа, утечек или злоупотребления.
#
# Общее внимание к обеспечению качества данных, способности к самообучению и безопасности информации является основой для успешной разработки решения на основе искусственного интеллекта. Эти факторы позволят создать надежное, эффективное и безопасное решение, которое сможет решать задачи с высокой точностью и уровнем доверия со стороны пользователей.

# %% [markdown]
# # Решение кейса

# %% [markdown]
# ## Анализ и задачи

# %% [markdown]
# Учитывая масштаб и разнообразие задач кейса, и для лучшего понимания, решено протестировать текущую работу контакт-центра. На основании полученного опыта, предложить варианты интеграции технологий искусственного интеллекта в данный кейс.

# %% [markdown]
# На текущий момент, у магазина Ашан имеется круглосуточная поддержка клиентов:
#
# - в тестовом формате:
#     - форма обратной связи (https://www.auchan.ru/feedback/)
#     - чат на официальном сайте (https://www.auchan.ru/)
#     - бот в Телеграм (https://t.me/AuchanRusbot)
#     - бот в Вайбер (viber://pa?chatURI=auchanrusbot)
# - в голосовом формате:
#      - многокональный телефон 8-800-700-5-800

# %% [markdown]
# <img src="img\auchan_chat.png" style='width:30%; float:left;' >
# <img src="img\auchan_telegram.png" style='width:30%;'>

# %% [markdown]
# Все текстовые сервисы имеют четко заданную структуру и алгоритмы для сбора данных относительно выбранного вопроса и предполагают, что пользователь точно знает, чего хочет и как должен действовать. Но на практике такое бывает не всегда, и чаще всего человеку просто нужна консультация. В этом случае у сервисов имеется возможность переключения пользователя на общение с сотрудником магазина.
#
# Наша задача состоит в том, чтобы простые и типичные вопросы, которые возникают у клиентов, решались в процессе диалога с интеллектуальным помошником. Это позволит снизить нагрузку на операторов и улучшить качество обслуживания, так как клиенты смогут задавать вопросы и получать ответы, как если бы они общались с живым человеком.

# %% [markdown]
# ## Что решено делать

# %% [markdown]
# Так как сроки решения кейса ограничены, а список задач достаточно широк, принято решение в качестве MVP создать телеграм-бота и интегрировать в него возможности современных генеративных сетей GPT для ответов на вопросы клиентов по теме Ашан.
#
# А если останется время, то можно будет дополнить проект такими возможностями, как CV (computer vision), TTS (text to speech) и VTT (voice to text). Например, для решения вопроса по возврату товара, покупатель сможет загрузить фотографии самого товара и чеков, а интеллектуальный помощник по фото определит товар и распознает информацию в чеке. Если кто-то не любит набирать текст, то сможет продиктовать сообщение голосом, и интеллектуальный помощник сможет преобразовать голосовое сообщение в текст и на него ответить. Ответ помощника также может быть озвучен.
#
# Для решения обозначенного круга вопросов и задач нам предоставлены все необходимые инструменты: доступ к облачным сервисам Яндекса и API-ключ Open AI для работы с моделями GPT.

# %% [markdown]
# **Примерная схема реализации сервиса "Интеллектуального помощника Ашанчик"**

# %% [markdown]
# <img src='img\bot_schema.png'>

# %% [markdown]
# **Основные проблемы**
#
# На сегодняшний день написание ботов и использование моделей GPT не является сверхзадачей, но есть проблемы, которые необходимо решить для достижения успеха:
#
# 1. Модели GPT устроены таким образом, что могут генерировать ответы по неограниченному кругу вопросов. Нам не нужна такая универсальность. Наша задача состоит в том, чтобы ограничить генерацию ответов тематикой, относящейся к магазинам "Ашан".
#
# 2. Известно, что модели GPT часто выдумывают недостоверную информацию, и это также один из критических моментов, так как выдуманная информация может ввести пользователя в заблуждение и это может негативно сказаться на репутации магазина. То есть, наш ассистент не должен искажать факты или выдумывать несуществующую информацию.
#
# 3. У всех моделей GPT есть технические ограничения по количеству токенов. Данный технический параметр определяет, какую глубину контекста в диалоге способна воспринимать модель. Это ограничение не дает нам возможности передать модели сразу всю базу знаний о магазине. То есть, нам необходимо реализовать механизм настройки модели под текущие узкие локальные задачи, например, информация о возврате товаров или информация по доставке товаров.

# %% [markdown]
# Учитывая указанные проблемы, мы протестировали разные генеративные модели на диалогах:
#
# - LLaMA2
# - YaGPT
# - ChatGPT gpt-3.5-turbo
# - ChatGPT gpt-3.5-turbo-16k
# - ChatGPT gpt-4

# %% [markdown]
# Для реализации мы выбрали модель gpt-4, т.к. она наилучшим образом соотвествует перечисленным требованиям.
#
# Приведем несколько примеров диалогов с данной моделью для решения задач возврата товаров.

# %% [markdown]
# **Пробуем задать простой вопрос не по теме:**
#
# ```
# Пользователь: Добрый день!
#
# Ашанчик: Добрый день! Чем я могу помочь вам сегодня?
#
# Пользователь: сколько будет 2+2?
#
# Ашанчик: Извините, но я могу отвечать только на вопросы, связанные с магазином Ашан.
# ```

# %% [markdown]
# **Пример диалога, когда не указан тип товара, дается общая информация о возврате:**
#
# ```
# Пользователь: Привет!
#
# Ашанчик: Привет! Чем я могу помочь вам сегодня?
#
# Пользователь: я купил испорченный товар
#
# Ашанчик: Очень жаль, что вы столкнулись с такой ситуацией. Если товар ненадлежащего качества, вы имеете право вернуть его или обменять.
#
# Если это продукт питания, и недостаток возник до передачи товара вам, он принимается на экспертизу для дальнейшего обмена или возврата денежных средств в пределах срока годности.
#
# Если это непродовольственный товар, и недостаток возник до передачи товара вам, он также принимается на экспертизу для дальнейшего обмена или возврата денежных средств не позднее, чем через 15 дней с момента покупки.
#
# Пожалуйста, обратитесь в ближайший магазин Ашан с товаром и чеком. Если у вас возникнут проблемы или вопросы, вы можете связаться с нашей службой поддержки по телефону 8-800-700-5-800.
# ```

# %% [markdown]
# **Пробуем вернуть непродовольственный товар:**
#
# ```
# Пользователь: Здравствуйте!
#
# Ашанчик: Здравствуйте! Чем я могу помочь вам сегодня?
#
# Пользователь: я три дня назад купил пудовую гирю, сегодня она раскололась пополам, куда можно обратиться с этой проблемой?
#
# Ашанчик: Очень жаль, что вы столкнулись с такой проблемой. В данном случае, вам следует обратиться в отдел обслуживания клиентов в магазине, где была совершена покупка. Пожалуйста, возьмите с собой товар и чек о покупке. Если недостаток возник не по вашей вине, товар будет принят на экспертизу для дальнейшего обмена или возврата денежных средств. Если у вас возникнут дополнительные вопросы, вы всегда можете обратиться в наш контактный центр по номеру 8-800-700-5-800.
#
# ```

# %% [markdown]
# **Пробуем вернуть продовольственный товар:**
#
# ```
# Пользователь: Добрый день!
#
# Ашанчик: Добрый день! Чем я могу помочь вам сегодня?
#
# Пользователь: Я купил сегодня арбуз, а он оказался кислым.
#
# Ашанчик: Очень жаль, что вы столкнулись с такой проблемой. Продукты питания ненадлежащего качества, при условии, что недостаток возник до передачи товара покупателю, в пределах срока годности, принимаются на экспертизу для дальнейшего обмена или возврата денежных средств. Пожалуйста, обратитесь в ближайший магазин Ашан с чеком и товаром.
#
# Пользователь: А куда я еще могу обратиться с этим вопросом?
#
# Ашанчик: Вы также можете обратиться в нашу круглосуточную клиентскую службу:
#
# - Форма обратной связи на нашем сайте: https://www.auchan.ru/feedback/
# - Контактный центр по телефону 8-800-700-5-800 (звонок бесплатный)
# - Чат-бот в Viber: viber://pa?chatURI=auchanrusbot
#
# Наши специалисты помогут вам решить вашу проблему.
# ```

# %% [markdown]
# **Попробуем сдать чужой товар:**
#
# ```
# Пользователь: Добрый вечер!
#
# Ашанчик: Добрый вечер! Чем я могу помочь вам сегодня?
#
# Пользователь: Купил в Магните хлеб с плесенью, как я могу его вам вернуть?
#
# Ашанчик: Извините, но я помощник магазина Ашан и могу помочь только с вопросами, связанными с нашим магазином. Вам следует обратиться в службу поддержки магазина "Магнит" для решения вашего вопроса.
# ```

# %% [markdown]
# **Пробуем сдать товар за пределами сроков возврата:**
#
# ```
# Пользователь: Доброе утро!
#
# Ашанчик: Доброе утро! Чем я могу помочь вам сегодня?
#
# Пользователь: Год назад купил у вас куртку, на ней разошелся замок, могу я ее вернуть?
#
# Ашанчик: К сожалению, возврат товаров надлежащего качества возможен только в течение 7 дней после покупки, при условии, что товар не был в употреблении, сохранен его первоначальный вид, комплектация и упаковка не повреждены. Если на товаре обнаружен производственный дефект, то возврат или обмен возможен в течение 15 дней. Однако, поскольку с момента покупки прошел год, возврат или обмен, к сожалению, невозможен. Рекомендую обратиться в специализированный ремонтный центр для устранения проблемы с замком.
# ```

# %% [markdown]
# **Пример ответа на голосовое сообщение:**
#
# <img src='img\auchan_voice.png' style='width:50%;'>

# %% [markdown]
# ## Выводы

# %% [markdown]
# 1. На текущий момент получен опыт настройки генеративной модели для ведения достаточно адекватных диалогов в пределах заданной тематики.
#
# 2. Выполнена интеграция модели с чат-ботом в Телеграм.
#
# 3. С помощью сервиса Яндекс Speechkit реализована возможность приема голосовых сообщений.

# %% [markdown]
# Мы понимаем, что не покрыли все функциональные требования заказчика, но готовы дальше работать в данном направлении.
